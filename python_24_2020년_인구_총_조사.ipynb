# %% [markdown]
# <a href="https://colab.research.google.com/github/eoooomji/python_demo_colab/blob/master/python_24_2020%EB%85%84_%EC%9D%B8%EA%B5%AC_%EC%B4%9D_%EC%A1%B0%EC%82%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## 구글 드라이브 연결
from google.colab import drive
drive.mount('/content/drive')

#  경로 변경
# %cd /content/drive/MyDrive/python_demo
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/python_demo

# %%
# %ls
# Out:
#  01_자료형_풀이.ipynb
#  01_자료형_문제.ipynb
#  02_제어문_풀이.ipynb
#  02_제어문_문제.ipynb
#  03_함수형프로그래밍_문제.ipynb
#  04_함수형프로그래밍_풀이.ipynb
# '05_정규표현식 풀이.ipynb'
# '05_정규표현식 문제.ipynb'
#  100_colab_환경설정.ipynb
#  101_파일_read_write.ipynb
#  data_crowing/
#  gosu2.txt
#  gosu3.txt
#  gosu.txt
#  ndata1.npy
#  ndata2.npz
#  ndata.csv
#  pdsample/
# '수업_파이썬 _ppt.zip'
#  python_01_Mark-Down.ipynb
#  python_02_basic.ipynb
#  python_03_statement.ipynb
#  python_04_function.ipynb
#  python_06_함수형프로그래밍.ipynb
#  python_07_class.ipynb
#  python_08_파일입출력.ipynb
#  python_09_정규표현식.ipynb
#  python_10_numpy.ipynb
#  python_11_numpy.ipynb
#  python_12_numpy.ipynb
#  python_13_데이터수집.ipynb
#  python_14_데이터수집_정적데이터.ipynb
#  python_15_hollys.ipynb
# 'python_16_데이터수집_정적데이터_도시별 기상청 날씨.ipynb'
#  python_17_selenium.ipynb
#  python_18_json.ipynb
# ...

# %% [markdown]
# ### Matplotlib의 그래프 한글 처리 - colab
#
# - 아래 코드 작성 후 설치 > 메뉴에서 런타임 다시 시작
#   ex )
#   plt.rc('font', family='NanumBarunGothic')
#   plt.title('제목')
#   plt.plot([1, 2, 3, 4, 5])

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %% [markdown]
# import

# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# https://kosis.kr/index/index.do

# %%
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc7 in position 0: invalid continuation byte
df_kosis = pd.read_csv('data_crowing/행정구역_시군구_별__성별_인구수_2020.csv')
df_kosis
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-22-d19b2b02d62a> in <module>
# ----> 1 df_kosis = pd.read_csv('data_crowing/행정구역_시군구_별__성별_인구수_2020.csv')
#       2 df_kosis
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# cp949 우리나라 코드 값
df_kosis = pd.read_csv('data_crowing/행정구역_시군구_별__성별_인구수_2020.csv', encoding='cp949')
df_kosis.head()
# Out:
#    행정구역(시군구)별      2020     2020.1     2020.2
# 0  행정구역(시군구)별  총인구수 (명)  남자인구수 (명)  여자인구수 (명)
# 1          전국  51829023   25841029   25987994
# 2       서울특별시   9668465    4701723    4966742
# 3       부산광역시   3391946    1661000    1730946
# 4       대구광역시   2418346    1193109    1225237

# %%
df_kosis['행정구역(시군구)별'].unique()
# Out:
# array(['행정구역(시군구)별', '전국', '서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시',
#        '대전광역시', '울산광역시', '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도',
#        '전라남도', '경상북도', '경상남도', '제주특별자치도'], dtype=object)

# %%
# 0번째 인덱스의 row 제거 : 행정구역(시군구)별	총인구수 (명)	남자인구수 (명)	여자인구수 (명)
df = df_kosis[df_kosis['행정구역(시군구)별'] != '행정구역(시군구)별'].copy()
df
# Out:
#    행정구역(시군구)별      2020    2020.1    2020.2
# 1          전국  51829023  25841029  25987994
# 2       서울특별시   9668465   4701723   4966742
# 3       부산광역시   3391946   1661000   1730946
# 4       대구광역시   2418346   1193109   1225237
# 5       인천광역시   2942828   1473943   1468885
# 6       광주광역시   1450062    717348    732714
# 7       대전광역시   1463882    730699    733183
# 8       울산광역시   1136017    583708    552309
# 9     세종특별자치시    355831    177568    178263
# 10        경기도  13427014   6754469   6672545
# 11        강원도   1542840    776505    766335
# 12       충청북도   1600837    811591    789246
# 13       충청남도   2121029   1082634   1038395
# 14       전라북도   1804104    896874    907230
# 15       전라남도   1851549    930615    920934
# 16       경상북도   2639422   1329211   1310211
# 17       경상남도   3340216   1681423   1658793
# 18    제주특별자치도    674635    338609    336026

# %%
# 전국 row 제거 : 전국	51829023	25841029	25987994
df = df[df['행정구역(시군구)별'] != '전국'].copy()
df
# Out:
#    행정구역(시군구)별      2020   2020.1   2020.2
# 2       서울특별시   9668465  4701723  4966742
# 3       부산광역시   3391946  1661000  1730946
# 4       대구광역시   2418346  1193109  1225237
# 5       인천광역시   2942828  1473943  1468885
# 6       광주광역시   1450062   717348   732714
# 7       대전광역시   1463882   730699   733183
# 8       울산광역시   1136017   583708   552309
# 9     세종특별자치시    355831   177568   178263
# 10        경기도  13427014  6754469  6672545
# 11        강원도   1542840   776505   766335
# 12       충청북도   1600837   811591   789246
# 13       충청남도   2121029  1082634  1038395
# 14       전라북도   1804104   896874   907230
# 15       전라남도   1851549   930615   920934
# 16       경상북도   2639422  1329211  1310211
# 17       경상남도   3340216  1681423  1658793
# 18    제주특별자치도    674635   338609   336026

# %%
df['행정구역(시군구)별'].unique()
# Out:
# array(['서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시',
#        '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도',
#        '경상남도', '제주특별자치도'], dtype=object)

# %%
df.info() # 행의 갯수, 기타 등등
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 2 to 18
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   행정구역(시군구)별  17 non-null     object
#  1   2020        17 non-null     object
#  2   2020.1      17 non-null     object
#  3   2020.2      17 non-null     object
# dtypes: object(4)
# memory usage: 680.0+ bytes

# %%
df.head()
# Out:
#   행정구역(시군구)별     2020   2020.1   2020.2
# 2      서울특별시  9668465  4701723  4966742
# 3      부산광역시  3391946  1661000  1730946
# 4      대구광역시  2418346  1193109  1225237
# 5      인천광역시  2942828  1473943  1468885
# 6      광주광역시  1450062   717348   732714

# %%
df['2020'] = [int(i) for i in df['2020']] # '2020' 값인 문자열을 숫자로 바꿔준다.

# %%
# df[['행정구역(시군구)별', '2020']]

# df.iloc[:, 0:2] # slicing / # df.iloc[:, [0, 1]] # fancy indexing

df = df.loc[:,'행정구역(시군구)별' : '2020']
df
# Out:
#    행정구역(시군구)별      2020
# 2       서울특별시   9668465
# 3       부산광역시   3391946
# 4       대구광역시   2418346
# 5       인천광역시   2942828
# 6       광주광역시   1450062
# 7       대전광역시   1463882
# 8       울산광역시   1136017
# 9     세종특별자치시    355831
# 10        경기도  13427014
# 11        강원도   1542840
# 12       충청북도   1600837
# 13       충청남도   2121029
# 14       전라북도   1804104
# 15       전라남도   1851549
# 16       경상북도   2639422
# 17       경상남도   3340216
# 18    제주특별자치도    674635

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 2 to 18
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   행정구역(시군구)별  17 non-null     object
#  1   2020        17 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 408.0+ bytes

# %%
print(dir(sns))
# Out:
# ['FacetGrid', 'JointGrid', 'PairGrid', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_core', '_decorators', '_docstrings', '_orig_rc_params', '_statistics', 'algorithms', 'axes_style', 'axisgrid', 'barplot', 'blend_palette', 'boxenplot', 'boxplot', 'categorical', 'catplot', 'choose_colorbrewer_palette', 'choose_cubehelix_palette', 'choose_dark_palette', 'choose_diverging_palette', 'choose_light_palette', 'clustermap', 'cm', 'color_palette', 'colors', 'countplot', 'crayon_palette', 'crayons', 'cubehelix_palette', 'dark_palette', 'desaturate', 'despine', 'displot', 'distplot', 'distributions', 'diverging_palette', 'dogplot', 'ecdfplot', 'external', 'factorplot', 'get_data_home', 'get_dataset_names', 'heatmap', 'histplot', 'hls_palette', 'husl_palette', 'jointplot', 'kdeplot', 'light_palette', 'lineplot', 'lmplot', 'load_dataset', 'matrix', 'miscplot', 'move_legend', 'mpl', 'mpl_palette', 'pairplot',
# ...

# %%
plt.rc('font', family = 'NanumBarunGothic')
plt.figure(figsize = (15, 4))
plt.xticks(rotation = 45)
sns.lineplot(data = df, x = '행정구역(시군구)별', y = '2020')

# %% [markdown]
# ## population_kosis_1997_2019.csv

# %%
df_kosis = pd.read_csv('pdsample/population_kosis_1997_2019.csv', encoding='cp949')
df_kosis
# Out:
#        시군구별 1997. 01 1997. 01.1 1997. 01.2 1997. 02 1997. 02.1 1997. 02.2  \
# 0      시군구별    계 (명)     남자 (명)     여자 (명)    계 (명)     남자 (명)     여자 (명)
# 1        전국    63268      33266      30002    58144      30086      28058
# 2     서울특별시    13205       6886       6319    12239       6224       6015
# 3     부산광역시     4201       2260       1941     3910       2104       1806
# 4     대구광역시     3345       1764       1581     2994       1608       1386
# 5     인천광역시     3646       1878       1768     3193       1646       1547
# 6     광주광역시     2166       1106       1060     1910        985        925
# 7     대전광역시     2003       1055        948     1869        927        942
# 8     울산광역시     1754        935        819     1569        838        731
# 9   세종특별자치시        -          -          -        -          -          -
# 10      경기도    13440       7086       6354    12334       6410       5924
# 11      강원도     1794        917        877     1648        844        804
# ...

# %%
df_kosis.shape
# Out:
# (19, 829)

# %%
# 모든 컬럼들이 보이도록 설정한다.
pd.options.display.max_columns = 829

# %%
df_kosis.head()
# Out:
#     시군구별 1997. 01 1997. 01.1 1997. 01.2 1997. 02 1997. 02.1 1997. 02.2  \
# 0   시군구별    계 (명)     남자 (명)     여자 (명)    계 (명)     남자 (명)     여자 (명)
# 1     전국    63268      33266      30002    58144      30086      28058
# 2  서울특별시    13205       6886       6319    12239       6224       6015
# 3  부산광역시     4201       2260       1941     3910       2104       1806
# 4  대구광역시     3345       1764       1581     2994       1608       1386
#
#   1997. 03 1997. 03.1 1997. 03.2 1997. 04 1997. 04.1 1997. 04.2 1997. 05  \
# 0    계 (명)     남자 (명)     여자 (명)    계 (명)     남자 (명)     여자 (명)    계 (명)
# 1    62160      32333      29827    56949      29449      27500    55270
# 2    13358       6947       6411    12146       6152       5994    11637
# 3     4304       2234       2070     3872       2026       1846     3826
# 4     3337       1815       1522     3025       1603       1422     2855
#
#   1997. 05.1 1997. 05.2 1997. 06 1997. 06.1 1997. 06.2 1997. 07 1997. 07.1  \
# ...

# %%
df = df_kosis.melt(id_vars = '시군구별')
df
# Out:
#           시군구별    variable  value
# 0         시군구별    1997. 01  계 (명)
# 1           전국    1997. 01  63268
# 2        서울특별시    1997. 01  13205
# 3        부산광역시    1997. 01   4201
# 4        대구광역시    1997. 01   3345
# ...        ...         ...    ...
# 15727     전라북도  2019. 12.2    290
# 15728     전라남도  2019. 12.2    353
# 15729     경상북도  2019. 12.2    455
# 15730     경상남도  2019. 12.2    646
# 15731  제주특별자치도  2019. 12.2    182
#
# [15732 rows x 3 columns]

# %%
df.shape
# Out:
# (15732, 3)

# %%
df['시군구별'].unique()
# Out:
# array(['시군구별', '전국', '서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시',
#        '울산광역시', '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도',
#        '경상북도', '경상남도', '제주특별자치도'], dtype=object)

# %%
df[df['시군구별'] == '시군구별']
# Out:
#        시군구별    variable   value
# 0      시군구별    1997. 01   계 (명)
# 19     시군구별  1997. 01.1  남자 (명)
# 38     시군구별  1997. 01.2  여자 (명)
# 57     시군구별    1997. 02   계 (명)
# 76     시군구별  1997. 02.1  남자 (명)
# ...     ...         ...     ...
# 15637  시군구별  2019. 11.1  남자 (명)
# 15656  시군구별  2019. 11.2  여자 (명)
# 15675  시군구별    2019. 12   계 (명)
# 15694  시군구별  2019. 12.1  남자 (명)
# 15713  시군구별  2019. 12.2  여자 (명)
#
# [828 rows x 3 columns]

# %%
df = df[df['시군구별'] != '시군구별'].copy()
df
# Out:
#           시군구별    variable  value
# 1           전국    1997. 01  63268
# 2        서울특별시    1997. 01  13205
# 3        부산광역시    1997. 01   4201
# 4        대구광역시    1997. 01   3345
# 5        인천광역시    1997. 01   3646
# ...        ...         ...    ...
# 15727     전라북도  2019. 12.2    290
# 15728     전라남도  2019. 12.2    353
# 15729     경상북도  2019. 12.2    455
# 15730     경상남도  2019. 12.2    646
# 15731  제주특별자치도  2019. 12.2    182
#
# [14904 rows x 3 columns]

# %%
df['시군구별'].unique()
# Out:
# array(['전국', '서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시',
#        '울산광역시', '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도',
#        '경상북도', '경상남도', '제주특별자치도'], dtype=object)

# %%
df.head()
# Out:
#     시군구별  variable  value
# 1     전국  1997. 01  63268
# 2  서울특별시  1997. 01  13205
# 3  부산광역시  1997. 01   4201
# 4  대구광역시  1997. 01   3345
# 5  인천광역시  1997. 01   3646

# %%
df.tail()
# Out:
#           시군구별    variable value
# 15727     전라북도  2019. 12.2   290
# 15728     전라남도  2019. 12.2   353
# 15729     경상북도  2019. 12.2   455
# 15730     경상남도  2019. 12.2   646
# 15731  제주특별자치도  2019. 12.2   182

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14904 entries, 1 to 15731
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시군구별      14904 non-null  object
#  1   variable  14904 non-null  object
#  2   value     14904 non-null  object
# dtypes: object(3)
# memory usage: 465.8+ KB

# %%
# Serise로 리턴
print(type(df['variable'])) # Series
print(df['variable'])
print(type(df['variable'].str)) # StringMethods
print(df['variable'].str.split('.')[1][0])
print(df['variable'].str.split('.')[1][1])
print(type(print(df['variable'].str.split('.'))))
print(df['variable'].str.split('.'))

# DataFrame으로 리턴
print(type(df['variable'].str.split('.', expand = True)))
print(df['variable'].str.split('.', expand = True))

# %%
df['연도'] = df['variable'].str.split('.', expand = True)[0]
df['월'] = df['variable'].str.split('.', expand = True)[1]
df['성별'] = df['variable'].str.split('.', expand = True)[2]

# %%
df.head()
# Out:
#     시군구별  variable  value    연도    월    성별
# 1     전국  1997. 01  63268  1997   01  None
# 2  서울특별시  1997. 01  13205  1997   01  None
# 3  부산광역시  1997. 01   4201  1997   01  None
# 4  대구광역시  1997. 01   3345  1997   01  None
# 5  인천광역시  1997. 01   3646  1997   01  None

# %%
df.tail()
# Out:
#           시군구별    variable value    연도    월 성별
# 15727     전라북도  2019. 12.2   290  2019   12  2
# 15728     전라남도  2019. 12.2   353  2019   12  2
# 15729     경상북도  2019. 12.2   455  2019   12  2
# 15730     경상남도  2019. 12.2   646  2019   12  2
# 15731  제주특별자치도  2019. 12.2   182  2019   12  2

# %%
# 모든 데이터 타입이 object이다. (object = string)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14904 entries, 1 to 15731
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시군구별      14904 non-null  object
#  1   variable  14904 non-null  object
#  2   value     14904 non-null  object
#  3   연도        14904 non-null  object
#  4   월         14904 non-null  object
#  5   성별        9936 non-null   object
# dtypes: object(6)
# memory usage: 1.3+ MB

# %%
# 성별에 None이 포함되어 있다.
df['성별'].unique()
# Out:
# array([None, '1', '2'], dtype=object)

# %%
# None 아닌 uinique 갯수만 반환한다.
df['성별'].nunique()
# Out:
# 2

# %%
df['성별'] = df['성별'].fillna('전체')

# %%
df.head()
# Out:
#     시군구별  variable  value    연도    월  성별
# 1     전국  1997. 01  63268  1997   01  전체
# 2  서울특별시  1997. 01  13205  1997   01  전체
# 3  부산광역시  1997. 01   4201  1997   01  전체
# 4  대구광역시  1997. 01   3345  1997   01  전체
# 5  인천광역시  1997. 01   3646  1997   01  전체

# %%
df.tail()
# Out:
#           시군구별    variable value    연도    월 성별
# 15727     전라북도  2019. 12.2   290  2019   12  2
# 15728     전라남도  2019. 12.2   353  2019   12  2
# 15729     경상북도  2019. 12.2   455  2019   12  2
# 15730     경상남도  2019. 12.2   646  2019   12  2
# 15731  제주특별자치도  2019. 12.2   182  2019   12  2

# %%
df['성별'].unique()
# Out:
# array(['전체', '1', '2'], dtype=object)

# %%
df['성별'] = df['성별'].replace('1', '남').replace('2', '여')
df['성별'].unique()
# Out:
# array(['전체', '남', '여'], dtype=object)

# %%
df.head()
# Out:
#     시군구별  variable  value    연도    월  성별
# 1     전국  1997. 01  63268  1997   01  전체
# 2  서울특별시  1997. 01  13205  1997   01  전체
# 3  부산광역시  1997. 01   4201  1997   01  전체
# 4  대구광역시  1997. 01   3345  1997   01  전체
# 5  인천광역시  1997. 01   3646  1997   01  전체

# %%
df.tail()
# Out:
#           시군구별    variable value    연도    월 성별
# 15727     전라북도  2019. 12.2   290  2019   12  여
# 15728     전라남도  2019. 12.2   353  2019   12  여
# 15729     경상북도  2019. 12.2   455  2019   12  여
# 15730     경상남도  2019. 12.2   646  2019   12  여
# 15731  제주특별자치도  2019. 12.2   182  2019   12  여

# %%
# Series에만 사용할 수 있다.
# 빈도수를 계산한다.
df['성별'].value_counts()
# Out:
# 전체    4968
# 남     4968
# 여     4968
# Name: 성별, dtype: int64

# %%
df = df.rename(columns = {'variable' : '기간', 'value' : '출생아수'})
df.head()
# Out:
#     시군구별        기간   출생아수    연도    월  성별
# 1     전국  1997. 01  63268  1997   01  전체
# 2  서울특별시  1997. 01  13205  1997   01  전체
# 3  부산광역시  1997. 01   4201  1997   01  전체
# 4  대구광역시  1997. 01   3345  1997   01  전체
# 5  인천광역시  1997. 01   3646  1997   01  전체

# %%
df['출생아수'].unique()
# Out:
# array(['63268', '13205', '4201', ..., '160', '2986', '10205'],
#       dtype=object)

# %%
df.sample(10)
# Out:
#           시군구별          기간  출생아수    연도    월  성별
# 15247  세종특별자치시  2019. 04.1   154  2019   04   남
# 9112       강원도  2010. 04.2   503  2010   04   여
# 15279    부산광역시    2019. 05  1456  2019   05  전체
# 5515     인천광역시  2005. 01.2  1011  2005   01   여
# 6672     부산광역시    2006. 10  2299  2006   10  전체
# 6649   제주특별자치도  2006. 09.1   276  2006   09   남
# 4933      충청북도  2004. 03.1   711  2004   03   남
# 6794       강원도    2006. 12   952  2006   12  전체
# 1869     대전광역시  1999. 09.2   743  1999   09   여
# 10406     충청남도  2012. 03.1   973  2012   03   남

# %%
df['출생아수'].unique()
# Out:
# array(['63268', '13205', '4201', ..., '160', '2986', '10205'],
#       dtype=object)

# %%
# '출생아수' 컬럼에서 '-'을 찾기 위한 작업
df['출생아수'] = df['출생아수'].replace('-', np.nan)

# %%
df.sample(10)
# Out:
#           시군구별          기간   출생아수    연도    월  성별
# 5118     대전광역시  2004. 06.2    603  2004   06   여
# 14362     경상남도  2017. 12.2    780  2017   12   여
# 2288     울산광역시    2000. 05   1311  2000   05  전체
# 7044      전라북도  2007. 04.1    750  2007   04   남
# 12117     전라북도  2014. 09.1    657  2014   09   남
# 14517       전국  2018. 03.2  14611  2018   03   여
# 4460      전라북도    2003. 07   1448  2003   07  전체
# 4607   세종특별자치시  2003. 09.2    NaN  2003   09   여
# 13667    광주광역시  2016. 12.2    381  2016   12   여
# 9757       경기도    2011. 04  10262  2011   04  전체

# %%
# '출생아수'의 데이터 타입을 확인한다.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14904 entries, 1 to 15731
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시군구별    14904 non-null  object
#  1   기간      14904 non-null  object
#  2   출생아수    14364 non-null  object
#  3   연도      14904 non-null  object
#  4   월       14904 non-null  object
#  5   성별      14904 non-null  object
# dtypes: object(6)
# memory usage: 1.3+ MB

# %%
df['출생아수'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-193-9b5ee33b496e> in <module>
# ----> 1 df['출생아수'].astype(int)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df['출생아수'] = df['출생아수'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14904 entries, 1 to 15731
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시군구별    14904 non-null  object
#  1   기간      14904 non-null  object
#  2   출생아수    14364 non-null  float64
#  3   연도      14904 non-null  object
#  4   월       14904 non-null  object
#  5   성별      14904 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 1.3+ MB

# %%
df.sample(10)
# Out:
#           시군구별          기간     출생아수    연도    월  성별
# 1126     인천광역시  1998. 08.2   1359.0  1998   08   여
# 12175     전라남도  2014. 10.1    614.0  2014   10   남
# 10441      경기도    2012. 04  10238.0  2012   04  전체
# 3706        전국    2002. 06  37575.0  2002   06  전체
# 13956      경기도  2017. 05.2   3869.0  2017   05   여
# 15082     전라남도  2019. 01.1    572.0  2019   01   남
# 4830     대구광역시  2004. 01.2   1031.0  2004   01   여
# 1999     대구광역시    1999. 12   2683.0  1999   12  전체
# 845    세종특별자치시  1998. 03.2      NaN  1998   03   여
# 6985      충청북도  2007. 03.1    629.0  2007   03   남

# %%
df['출생아수'].describe()
# Out:
# count    14364.000000
# mean      3072.798942
# std       6683.035581
# min         30.000000
# 25%        638.000000
# 50%       1045.000000
# 75%       1947.000000
# max      63268.000000
# Name: 출생아수, dtype: float64

# %% [markdown]
# ### 전국별 성별 전체

# %%
df.head()
# Out:
#     시군구별        기간     출생아수    연도    월  성별
# 1     전국  1997. 01  63268.0  1997   01  전체
# 2  서울특별시  1997. 01  13205.0  1997   01  전체
# 3  부산광역시  1997. 01   4201.0  1997   01  전체
# 4  대구광역시  1997. 01   3345.0  1997   01  전체
# 5  인천광역시  1997. 01   3646.0  1997   01  전체

# %%
df_all = df[(df['시군구별'] == '전국') & (df['성별'] == '전체')]
print(df_all['시군구별'].unique())
print(df_all['성별'].unique())
print(df_all)
# Out:
# ['전국']
# ['전체']
#       시군구별        기간     출생아수    연도    월  성별
# 1       전국  1997. 01  63268.0  1997   01  전체
# 58      전국  1997. 02  58144.0  1997   02  전체
# 115     전국  1997. 03  62160.0  1997   03  전체
# 172     전국  1997. 04  56949.0  1997   04  전체
# 229     전국  1997. 05  55270.0  1997   05  전체
# ...    ...       ...      ...   ...  ...  ..
# 15448   전국  2019. 08  24371.0  2019   08  전체
# 15505   전국  2019. 09  24090.0  2019   09  전체
# 15562   전국  2019. 10  25613.0  2019   10  전체
# 15619   전국  2019. 11  23727.0  2019   11  전체
# 15676   전국  2019. 12  21228.0  2019   12  전체
#
# [276 rows x 6 columns]

# %%
df_all.head()
# Out:
#     시군구별        기간     출생아수    연도    월  성별
# 1     전국  1997. 01  63268.0  1997   01  전체
# 58    전국  1997. 02  58144.0  1997   02  전체
# 115   전국  1997. 03  62160.0  1997   03  전체
# 172   전국  1997. 04  56949.0  1997   04  전체
# 229   전국  1997. 05  55270.0  1997   05  전체

# %%
df_all.tail()
# Out:
#       시군구별        기간     출생아수    연도    월  성별
# 15448   전국  2019. 08  24371.0  2019   08  전체
# 15505   전국  2019. 09  24090.0  2019   09  전체
# 15562   전국  2019. 10  25613.0  2019   10  전체
# 15619   전국  2019. 11  23727.0  2019   11  전체
# 15676   전국  2019. 12  21228.0  2019   12  전체

# %%
# pandas를 통한 시각화

df_all.set_index(['연도', '월']).plot(figsize = (15, 5))

# %%
# 막대 그래프는 x축에 연도, 월을 모두 표시한다.
# df_all.set_index(['연도', '월']).plot(kind = 'bar', figsize = (15, 5))
df_all.set_index(['연도', '월']).plot.bar(figsize = (15, 5))

# %%
df_all[].set_index(['연도', '월']).plot.bar(figsize = (15, 5))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-223-42d32c2fea43> in <module>
# ----> 1 df_all['출생아수'].set_index(['연도', '월']).plot.bar(figsize = (15, 5))
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'set_index'

# %%
df_all[-24:]
# Out:
#       시군구별        기간     출생아수    연도    월  성별
# 14365   전국  2018. 01  32198.0  2018   01  전체
# 14422   전국  2018. 02  27575.0  2018   02  전체
# 14479   전국  2018. 03  29987.0  2018   03  전체
# 14536   전국  2018. 04  27734.0  2018   04  전체
# 14593   전국  2018. 05  27949.0  2018   05  전체
# 14650   전국  2018. 06  26357.0  2018   06  전체
# 14707   전국  2018. 07  27033.0  2018   07  전체
# 14764   전국  2018. 08  27381.0  2018   08  전체
# 14821   전국  2018. 09  26066.0  2018   09  전체
# 14878   전국  2018. 10  26474.0  2018   10  전체
# 14935   전국  2018. 11  25301.0  2018   11  전체
# 14992   전국  2018. 12  22767.0  2018   12  전체
# 15049   전국  2019. 01  30271.0  2019   01  전체
# 15106   전국  2019. 02  25710.0  2019   02  전체
# 15163   전국  2019. 03  27049.0  2019   03  전체
# 15220   전국  2019. 04  26104.0  2019   04  전체
# 15277   전국  2019. 05  25299.0  2019   05  전체
# 15334   전국  2019. 06  23992.0  2019   06  전체
# 15391   전국  2019. 07  25222.0  2019   07  전체
# 15448   전국  2019. 08  24371.0  2019   08  전체
# ...

# %%
df_all[-24:]['연도'].unique()
# Out:
# array(['2018', '2019'], dtype=object)

# %%
# 최근 2년(24개만)의 데이터를 가져와서 그래프로 그려준다.
df_all[-24:].set_index(['연도', '월']).plot.bar(figsize = (15, 5))

# %%
# seaborn 통한 시각화

df_all.head()
# Out:
#     시군구별        기간     출생아수    연도    월  성별
# 1     전국  1997. 01  63268.0  1997   01  전체
# 58    전국  1997. 02  58144.0  1997   02  전체
# 115   전국  1997. 03  62160.0  1997   03  전체
# 172   전국  1997. 04  56949.0  1997   04  전체
# 229   전국  1997. 05  55270.0  1997   05  전체

# %%
plt.figure(figsize = (15, 5))
sns.lineplot(data = df_all, x='연도', y='출생아수') # 근접값을 가져옴

plt.figure(figsize = (15, 5))
sns.lineplot(data = df_all, x='연도', y='출생아수', ci = None)

plt.figure(figsize = (15, 5))
sns.lineplot(data = df_all, x='연도', y='출생아수', ci = None, hue = '월')

# %%
plt.figure(figsize = (15, 5))
sns.barplot(data = df_all, x='연도', y='출생아수') # 근접값을 가져옴

plt.figure(figsize = (15, 5))
sns.barplot(data = df_all, x='연도', y='출생아수', ci = None)

plt.figure(figsize = (15, 5))
sns.barplot(data = df_all, x='연도', y='출생아수', ci = None, hue = '월')

# %% [markdown]
# ### 지역별 출생아수

# %%
df_local = df[df['시군구별'] != '전국'].copy()
df_local
# Out:
#           시군구별          기간     출생아수    연도    월  성별
# 2        서울특별시    1997. 01  13205.0  1997   01  전체
# 3        부산광역시    1997. 01   4201.0  1997   01  전체
# 4        대구광역시    1997. 01   3345.0  1997   01  전체
# 5        인천광역시    1997. 01   3646.0  1997   01  전체
# 6        광주광역시    1997. 01   2166.0  1997   01  전체
# ...        ...         ...      ...   ...  ...  ..
# 15727     전라북도  2019. 12.2    290.0  2019   12   여
# 15728     전라남도  2019. 12.2    353.0  2019   12   여
# 15729     경상북도  2019. 12.2    455.0  2019   12   여
# 15730     경상남도  2019. 12.2    646.0  2019   12   여
# 15731  제주특별자치도  2019. 12.2    182.0  2019   12   여
#
# [14076 rows x 6 columns]

# %%
df_local['시군구별'].unique()
# Out:
# array(['서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시',
#        '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도',
#        '경상남도', '제주특별자치도'], dtype=object)

# %%
plt.figure(figsize = (15, 5))
sns.lineplot(data = df_local, x = '연도', y = '출생아수', hue = '성별')

# %%
plt.figure(figsize = (15, 5))
sns.pointplot(data = df_local, x = '연도', y = '출생아수', hue = '성별')

# %%
# 전체만 가져오기
df_local = df_local[df['성별'] == '전체']
df_local.head()
# Out:
# <ipython-input-250-2dfbb320fe8b>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_local = df_local[df['성별'] == '전체']
#     시군구별        기간     출생아수    연도    월  성별
# 2  서울특별시  1997. 01  13205.0  1997   01  전체
# 3  부산광역시  1997. 01   4201.0  1997   01  전체
# 4  대구광역시  1997. 01   3345.0  1997   01  전체
# 5  인천광역시  1997. 01   3646.0  1997   01  전체
# 6  광주광역시  1997. 01   2166.0  1997   01  전체

# %%
df_local['성별'].unique()
# Out:
# array(['전체'], dtype=object)

# %%
plt.figure(figsize = (15, 5))
sns.pointplot(data = df_local, x = '연도', y = '출생아수', hue = '성별')

plt.figure(figsize = (15, 5))
sns.pointplot(data = df_local, x = '연도', y = '출생아수', hue = '시군구별')

plt.figure(figsize = (15, 5))
sns.pointplot(data = df_local, x = '연도', y = '출생아수', hue = '시군구별')
plt.legend(loc = 'center right')

# %%
df_loc_2 = df_local[df_local['시군구별'].isin(['서울특별시', '경기도', '세종특별자치시'])]
df_loc_2
# Out:
#           시군구별        기간     출생아수    연도    월  성별
# 2        서울특별시  1997. 01  13205.0  1997   01  전체
# 9      세종특별자치시  1997. 01      NaN  1997   01  전체
# 10         경기도  1997. 01  13440.0  1997   01  전체
# 59       서울특별시  1997. 02  12239.0  1997   02  전체
# 66     세종특별자치시  1997. 02      NaN  1997   02  전체
# ...        ...       ...      ...   ...  ...  ..
# 15627  세종특별자치시  2019. 11    310.0  2019   11  전체
# 15628      경기도  2019. 11   6607.0  2019   11  전체
# 15677    서울특별시  2019. 12   3670.0  2019   12  전체
# 15684  세종특별자치시  2019. 12    274.0  2019   12  전체
# 15685      경기도  2019. 12   5861.0  2019   12  전체
#
# [828 rows x 6 columns]

# %%
df_loc_2['시군구별'].unique()
# Out:
# array(['서울특별시', '세종특별자치시', '경기도'], dtype=object)

# %%
plt.figure(figsize = (15, 5))
sns.pointplot(data = df_loc_2, x = '연도', y='출생아수', hue = '시군구별')

# %%
df_loc_3 = df_loc_2[df_loc_2['시군구별'] == '세종특별자치시'].dropna()
df_loc_3.head()
# Out:
#           시군구별        기간  출생아수    연도    월  성별
# 10269  세종특별자치시  2012. 01  73.0  2012   01  전체
# 10326  세종특별자치시  2012. 02  74.0  2012   02  전체
# 10383  세종특별자치시  2012. 03  92.0  2012   03  전체
# 10440  세종특별자치시  2012. 04  84.0  2012   04  전체
# 10497  세종특별자치시  2012. 05  72.0  2012   05  전체

# %%
df_loc_3['시군구별'].unique()
# Out:
# array(['세종특별자치시'], dtype=object)

# %%
plt.figure(figsize = (15, 5))
sns.pointplot(data = df_loc_3, x = '연도', y = '출생아수')
