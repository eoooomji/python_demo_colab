# %% [markdown]
# <a href="https://colab.research.google.com/github/eoooomji/python_demo_colab/blob/master/python_19_%EA%B3%B5%EA%B3%B5%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%9E%90%EC%A0%84%EA%B1%B0_%EC%82%AC%EA%B3%A0_%EB%8B%A4%EB%B0%9C_%EC%A7%80%EC%97%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 공공데이터 포털
#
# - https://www.data.go.kr/index.do
#
# - 주소 : https://www.data.go.kr/data/15056681/openapi.do
# ( 도로교통공단_자전거 사고 다발지역 정보 서비스)

# %%
## 구글 드라이브 연결
from google.colab import drive
drive.mount('/content/drive')

#  경로 변경
# %cd /content/drive/MyDrive/python_demo
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/python_demo

# %%
import requests
import json
import sys

# %%
url = 'http://apis.data.go.kr/B552061/frequentzoneBicycle/getRestFrequentzoneBicycle'
# key = '5jf8VPZj4mhOoHu8nKZ5QFU4JF8qhqxaFux0aZv1c%2B%2BEqWtDWSU2Y3hhquGpCl%2BlzEpowLxmC4ajrgHzBizgyQ%3D%3D'
key = '5jf8VPZj4mhOoHu8nKZ5QFU4JF8qhqxaFux0aZv1c++EqWtDWSU2Y3hhquGpCl+lzEpowLxmC4ajrgHzBizgyQ=='

params ={'serviceKey' : key, 'searchYearCd' : '2019', 'siDo' : '', 'guGun' : '', 'type' : 'json', 'numOfRows' : '10', 'pageNo' : '1' }

response = requests.get(url, params=params)
print(dir(response))
print(response.content)
print(response.text)
print(type(response.content)) # bytes
print(type(response.text)) # str

# response.json()
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']
# ...

# %% [markdown]
# ### 분석 작업

# %%
# item 접근
w_data = response.json()['items']['item']
# print(w_data)

for i in range(len(w_data)) :
  print('spot_nm : ' + w_data[i]['spot_nm'])
  print('경도 : ' + w_data[i]['lo_crd'])
  print('위도 : ' + w_data[i]['la_crd'])
# Out:
# spot_nm : 서울특별시 종로구 서린동(종로구청입구 부근)
# 경도 : 126.979382406174
# 위도 : 37.569908240574
# spot_nm : 서울특별시 중구 을지로6가(신평화시장 부근)
# 경도 : 127.011030895261
# 위도 : 37.569606132218
# spot_nm : 서울특별시 용산구 서빙고동(반포대교북단 부근)
# 경도 : 126.994403745438
# 위도 : 37.519305786634
# spot_nm : 서울특별시 용산구 이촌동(이촌동길대건로진입로1 부근)
# 경도 : 126.961543277801
# 위도 : 37.522700893732
# spot_nm : 서울특별시 성동구 성수동2가(뚝도시장 부근)
# 경도 : 127.054828368136
# 위도 : 37.53909328273
# spot_nm : 서울특별시 성동구 성수동1가(개풍빌딩 부근)
# 경도 : 127.049393729938
# 위도 : 37.546531176074
# spot_nm : 서울특별시 성동구 성수동1가(성수여중 부근)
# 경도 : 127.049600255648
# 위도 : 37.540239434503
# spot_nm : 서울특별시 성동구 성수동1가(대림아파트 부근)
# 경도 : 127.044264503305
# 위도 : 37.542058623608
# spot_nm : 서울특별시 광진구 군자동(능동119안전센터 부근)
# 경도 : 127.078521185505
# 위도 : 37.555579967442
# spot_nm : 서울특별시 광진구 구의동(광진우체국 부근)
# 경도 : 127.089786315587
# 위도 : 37.538076112623

# %%
print(response.status_code == 200)
# Out:
# True

# %%
responseData = response.text
print(responseData)

if response.status_code == 200 :
  dictdata = json.loads(responseData) # str을 dict로 변환
  print(type(dictdata))
  print(dictdata)

  # xd = xmltodict.parse(responseData) # XML형식의 데이터를 dict 형식으로 변환
  # xdj = json.dumps(xd, ensure_ascii=Fasle) # dict형식의 데이터를 json형식으로 변환
  # xdjd = json.loads(xdj) # json형식의 데이터를 dict형식으로 변환
  # djd = json.loads(responseData) # str을 dict로 변환
# Out:
# {"resultCode":"00","resultMsg":"NORMAL_CODE","items":{"item":[{"afos_fid":6618237,"afos_id":"2020037","bjd_cd":"1111012300","spot_cd":"11110001","sido_sgg_nm":"서울특별시 종로구1","spot_nm":"서울특별시 종로구 서린동(종로구청입구 부근)","occrrnc_cnt":5,"caslt_cnt":5,"dth_dnv_cnt":0,"se_dnv_cnt":2,"sl_dnv_cnt":3,"wnd_dnv_cnt":0,"geom_json":"{\"type\":\"Polygon\",\"coordinates\":[[[126.98117904,37.56990824],[126.98114451,37.56963043],[126.98104228,37.56936329],[126.98087625,37.56911709],[126.98065282,37.56890129],[126.98038056,37.5687242],[126.98006995,37.5685926],[126.97973291,37.56851156],[126.97938241,37.5684842],[126.9790319,37.56851156],[126.97869487,37.5685926],[126.97838425,37.5687242],[126.978112,37.56890129],[126.97788856,37.56911709],[126.97772254,37.56936329],[126.9776203,37.56963043],[126.97758578,37.56990824],[126.9776203,37.57018605],[126.97772254,37.57045319],[126.97788856,37.57069938],[126.978112,37.57091517],[126.97838425,37.57109227],[126.97869487,37.57122386],[126.9790319,37.57130489],[126.9793
# ...
